# %% [markdown]
# <a href="https://colab.research.google.com/github/Rasheed-Bennett/Cuaderno/blob/main/Cuaderno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Semana 1 - Pseudocodigo

# %% [markdown]
# ###Contador de Digitos
# Usando psaint crear un diagrama de flujo para representar el flujo y el pseudocodigo de contarDigitos
#  *Recibira dos parametro
#  *Ambos mayores a cero
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Pseudocodigo

# %% [markdown]
# #### PSeudo código
# ```
# Algoritmo contarDigitos
# 	total = 0
# 	Leer a
# 	Mientras a > 0 Hacer
# 		// Realiza la operación
# 		a = trunc(a / 10)
# 		total = total + 1
# 	FinMientras
# 	Escribir total
# FinAlgoritmo
# ```
