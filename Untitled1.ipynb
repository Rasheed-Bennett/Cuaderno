# %% [markdown]
# <a href="https://colab.research.google.com/github/Rasheed-Bennett/Cuaderno/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# def sumaImpares(num, num2):
#     if isinstance(num, int) and 0 < num:
#         if isinstance(num2, int) and 0 < num2:
#             resultado = 0
#             while num > 0 and num2 > 0:
#                 impar = num % 10
#                 impar2 = num2 % 10
#                 num //= 10
#                 num2 //= 10
#                 if impar % 2 == 1:
#                     resultado += impar
#                     if impar2 % 2 == 1:
#                         resultado += impar2
#                     else:
#                         continue
#                 else:
#                     if impar2 % 2 == 1:
#                         resultado += impar2
#                     else:
#                         continue
#             return resultado
#         else:
#             return "Error num2 debe ser un numero entero positivo mayor a 0"
#     else:
#         return "Error: debe ingresar un numero entero positivo mayor a 0"
#
# def sumaImpares_for(num, num2):
#     if isinstance(num, int) and 0 < num:
#         if isinstance(num2, int) and 0 < num2:
#             digitos = mayorDigito(num, num2)
#             resultado = 0
#             for numero in range(digitos):
#                 impar = num % 10
#                 impar2 = num2 % 10
#                 num //= 10
#                 num2 //= 10
#                 if impar % 2 == 1:
#                     resultado += impar
#                     if impar2 % 2 == 1:
#                         resultado += impar2
#                     else:
#                         continue
#                 else:
#                     if impar2 % 2 == 1:
#                         resultado += impar2
#                     else:
#                         continue
#             return resultado
#         else:
#             return "Error num2 debe ser un numero entero positivo mayor a 0"
#     else:
#         return "Error: debe ingresar un numero entero positivo mayor a 0"
#
# def mayorDigito(num1, num2):
#     digitos1 = 0
#     digitos2 = 0
#     while num1 != 0:
#         digitos1 += 1
#         num1 //= 10
#     while num2 != 0:
#         digitos2 += 1
#         num2 //= 10
#     if digitos1 <= digitos2:
#         return digitos2
#     else:
#         return digitos1
#
# def sumaImpares_cola(num1, num2):
#     if isinstance(num1, int) and 0 < num1:
#         if isinstance(num2, int) and 0 < num2:
#             return sumaImpares_cola_Aux(num1, num2, 0)
#         else:
#             return "Error num2 debe ser un numero entero positivo mayor a 0"
#     else:
#         return "Error: debe ingresar un numero entero positivo mayor a 0"
#
# def sumaImpares_cola_Aux(num1, num2, resultado):
#     impar1 = num1 % 10
#     impar2 = num2 % 10
#     if num1 <= 0 and num2 <= 0:
#         return resultado
#     else:
#         if impar1 % 2 == 1:
#             resultado += num1
#             if impar2 % 2 == 1:
#                 resultado += impar2
#                 return sumaImpares_cola_Aux(num1//10, num2//10, resultado)
#             else:
#                 return sumaImpares_cola_Aux(num1//10, num2//10, resultado)
#         else:
#             if impar2 % 2 == 1:
#                 resultado += impar2
#                 return sumaImpares_cola_Aux(num1//10, num2//10, resultado)
#             else:
#                 return sumaImpares_cola_Aux(num1//10, num2//10, resultado)
#
# def sumaImpares_pila(num1, num2):
#     if isinstance(num1, int) and 0 < num1:
#         if isinstance(num2, int) and 0 < num2:
#             return sumaImpares_pila_Aux(num1, num2)
#         else:
#             return "Error num2 debe ser un numero entero positivo mayor a 0"
#     else:
#         return "Error: debe ingresar un numero entero positivo mayor a 0"
#
# def sumaImpares_pila_Aux(num1, num2):
#     impar1 = num1 % 10
#     impar2 = num2 % 10
#     if num1 <= 0 and num2 <= 0:
#         return impar1 + impar2
#     else:
#         if impar1 % 2 == 1:
#             return impar1 + sumaImpares_fila_Aux(num1//10, num2)
#         elif impar2 % 2 == 1:
#             return impar2 + sumaImpares_fila_Aux(num1, num2//10)
#         else:
#             return sumaImpares_fila_Aux(num1//10, num2//10)
#
# def sumaListaImpares_while(lista):
#     if isinstance(lista, list):
#          for elementos in lista:
#              if isinstance(elementos, int) and elementos > 0:
#                  continue
#              else:
#                 return "Error: los elementos de lista deben ser numeros enteros positivos"
#          return sumaListaImpares_while_Aux(lista)
#     else:
#         return "Error debe igresar una lista"
#
# def sumaListaImpares_while_Aux(lista):
#     resultado = 0
#     while lista != []:
#         if lista[0] == 0:
#             lista = lista[1:]
#         else:
#             impar = lista[0] % 10
#             lista[0] = lista[0] // 10
#             if impar % 2 == 1:
#                 resultado += impar
#             else:
#                 continue
#     return resultado
#
# def sumaListaImpares_for(lista):
#     if isinstance(lista, list):
#          for elementos in lista:
#              if isinstance(elementos, int) and elementos > 0:
#                  continue
#              else:
#                 return "Error: los elementos de lista deben ser numeros enteros positivos"
#          return sumaListaImpares_for_Aux(lista)
#     else:
#         return "Error debe igresar una lista"
#
# def sumaListaImpares_for_Aux(lista):
#     resultado = 0
#     for num in lista:
#         for i in range(num):
#             impar = num % 10
#             if num <= 0:
#                 break
#             else:
#                 if impar % 2 == 1:
#                     resultado += impar
#                     num //= 10
#                 else:
#                     num //= 10
#                     continue
#     return resultado
#
# def sumaListaImpares_pila(lista):
#     if isinstance(lista, list):
#          for elementos in lista:
#              if isinstance(elementos, int) and elementos > 0:
#                  continue
#              else:
#                 return "Error: los elementos de lista deben ser numeros enteros positivos"
#          return sumaListaImpares_pila_Aux(lista)
#     else:
#         return "Error debe igresar una lista"
#
# def sumaListaImpares_pila_Aux(lista):
#     if lista == []:
#         return 0
#     else:
#         if lista[0] == 0:
#             return sumaListaImpares_pila_Aux(lista[1:])
#         else:
#             impar = lista[0] % 10
#             lista[0] //= 10
#             if impar % 2 == 1:
#                 return impar + sumaListaImpares_pila_Aux(lista)
#             else:
#                 return sumaListaImpares_pila_Aux(lista)
#
# def sumaListaImpares_cola(lista):
#     if isinstance(lista, list):
#          for elementos in lista:
#              if isinstance(elementos, int) and elementos > 0:
#                  continue
#              else:
#                 return "Error: los elementos de lista deben ser numeros enteros positivos"
#          return sumaListaImpares_cola_Aux(lista, 0)
#     else:
#         return "Error debe igresar una lista"
#
# def sumaListaImpares_cola_Aux(lista, resultado):
#     if lista == []:
#         return resultado
#     else:
#         if lista[0] == 0:
#             return sumaListaImpares_cola_Aux(lista[1:], resultado)
#         else:
#             impar = lista[0] % 10
#             lista[0] //= 10
#             if impar % 2 == 1:
#                 return sumaListaImpares_cola_Aux(lista, resultado + impar)
#             else:
#                 return sumaListaImpares_cola_Aux(lista, resultado)
#
# ```
